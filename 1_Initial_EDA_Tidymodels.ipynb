# %% [markdown]
# # **Mushroom Classification - Playground Series**

# %% [markdown]
# ### **Set-up**

# %%
setwd("~/Google Drive/My Drive/DS_Projects/Playground_Series/ps4s8_Mushroom_Classification/")
options(scipen = 9999)

# %%
# Loading libraries
library(tidyverse)
library(effectsize)
library(naniar)
library(tidymodels)
library(yardstick)
library(tune)
library(bonsai)
library(doParallel)
library(embed)
library(discrim)
# Out:
# -- Attaching core tidyverse packages ------------------------ tidyverse 2.0.0 --
# v dplyr     1.1.2     v readr     2.1.4
# v forcats   1.0.0     v stringr   1.5.0
# v ggplot2   3.4.3     v tibble    3.2.1
# v lubridate 1.9.2     v tidyr     1.3.0
# v purrr     1.0.1
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
# i Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Warning message:
# "package 'effectsize' was built under R version 4.3.3"
# Warning message:
# "package 'naniar' was built under R version 4.3.1"
# -- Attaching packages -------------------------------------- tidymodels 1.1.0 --
#
# v broom        1.0.4      v rsample      1.1.1
# v dials        1.2.0      v tune         1.1.1
# v infer        1.0.4      v workflows    1.1.3
# v modeldata    1.2.0      v workflowsets 1.0.1
# v parsnip      1.1.0      v yardstick    1.2.0
# v recipes      1.0.10
#
# Warning message:
# "package 'recipes' was built under R version 4.3.1"
# -- Conflicts ----------------------------------------- tidymodels_conflicts() --
# x scales::discard() masks purrr::discard()
# x dplyr::filter()   masks stats::filter()
# x recipes::fixed()  masks stringr::fixed()
# x dplyr::lag()      masks stats::lag()
# x yardstick::spec() masks readr::spec()
# x recipes::step()   masks stats::step()
# * Use suppressPackageStartupMessages() to eliminate package startup messages
#
# Loading required package: foreach
#
#
# Attaching package: 'foreach'
#
#
# The following objects are masked from 'package:purrr':
#
#     accumulate, when
#
#
# Loading required package: iterators
#
# Loading required package: parallel
#
# Warning message:
# "package 'embed' was built under R version 4.3.1"
#
# Attaching package: 'discrim'
#
#
# The following object is masked from 'package:dials':
#
#     smoothness

# %%
train <- read_csv("Data/train.csv")
test <- read_csv("Data/test.csv")
submission <- read_csv("Data/sample_submission.csv")

# Correct column names 
col_names <- colnames(train)
col_names <- gsub("-", "_", col_names)
colnames(train) <- col_names

col_names <- colnames(test)
col_names <- gsub("-", "_", col_names)
colnames(test) <- col_names
features <- train %>% select(-id, -class) %>% colnames()
# Out:
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 3116945 Columns: 22
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr (16): class, cap-shape, cap-surface, cap-color, gill-attachment, gill-sp...
# dbl  (4): id, cap-diameter, stem-height, stem-width
# lgl  (2): does-bruise-or-bleed, has-ring
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 2077964 Columns: 21
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr (15): cap-shape, cap-surface, cap-color, gill-attachment, gill-spacing, ...
# dbl  (4): id, cap-diameter, stem-height, stem-width
# lgl  (2): does-bruise-or-bleed, has-ring
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 2077964 Columns: 2
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr (1): class
# dbl (1): id
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
# To improve visualization of the plots
my_theme <- function() {
  theme_bw() +
  theme(
    text = element_text(size = 20),
    axis.text = element_text(size = 18),
    axis.title = element_text(size = 20),
    legend.text = element_text(size = 18),
    legend.title = element_text(size = 20),
    plot.title = element_text(size = 24),
  )
}

# %% [markdown]
# ### **Missing Data Exploration**

# %%
# Lets see missing data with naniar package
gg_miss_var(train) + my_theme() + xlab("")
# Out:
# plot without title

# %%
# Missing data Train
# Columns with over 80% missing are: veil_color, stem_root, spore_print_color, veil_type
train_missing <- train %>% 
  map_df(is.na) %>% 
  map_df(sum) %>% 
  pivot_longer(cols = everything(), names_to = "features", values_to = "na_count") %>%
  mutate(pct = round(na_count/nrow(train),3)) %>% 
  arrange(desc(na_count)) 

test_missing  <- test %>% 
  map_df(is.na) %>% 
  map_df(sum) %>% 
  pivot_longer(cols = everything(), names_to = "features", values_to = "na_count") %>%
  gather(features, na_count) %>% 
  mutate(pct = round(na_count/nrow(test),3)) %>% 
  arrange(desc(na_count)) 

# Proportion of missing data are identical between train and test
train_missing %>% 
  left_join(test_missing, by = "features", suffix = c("_train", "_test"))
# Out:
#    features             na_count_train pct_train na_count_test pct_test
# 1  veil_type            2957493        0.949     1971545       0.949
# 2  spore_print_color    2849682        0.914     1899617       0.914
# 3  stem_root            2757023        0.885     1838012       0.885
# 4  veil_color           2740947        0.879     1826124       0.879
# 5  stem_surface         1980861        0.636     1321488       0.636
# 6  gill_spacing         1258435        0.404      839595       0.404
# 7  cap_surface           671023        0.215      446904       0.215
# 8  gill_attachment       523936        0.168      349821       0.168
# 9  ring_type             128880        0.041       86195       0.041
# 10 has_ring                 143        0.000         113       0.000
# 11 does_bruise_or_bleed     117        0.000          75       0.000
# 12 gill_color                57        0.000          49       0.000
# 13 habitat                   45        0.000          25       0.000
# 14 cap_shape                 40        0.000          31       0.000
# 15 stem_color                38        0.000          21       0.000
# 16 cap_color                 12        0.000          13       0.000
# 17 cap_diameter               4        0.000           7       0.000
# 18 id                         0        0.000           0       0.000
# 19 class                      0        0.000          NA          NA
# 20 stem_height                0        0.000           1       0.000
# 21 stem_width                 0        0.000           0       0.000
# 22 season                     0        0.000           0       0.000

# %%
# Whats up with veil_type? Almost 95% missing data
train %>% 
  count(veil_type) %>% 
  arrange(desc(n))  %>% 
  left_join(test %>% count(veil_type), by = "veil_type", suffix = c("_train", "_test"))

# Mainly one value, missing could be a category in this case
# This also applies to test
# Out:
#    veil_type n_train n_test
# 1  NA        2957493 1971545
# 2  u          159373  106373
# 3  w              11      12
# 4  a               9       2
# 5  e               8       6
# 6  f               8      NA
# 7  b               5       1
# 8  c               5       2
# 9  g               4       3
# 10 k               4       5
# 11 y               4       3
# 12 n               3       3
# 13 s               3       3
# 14 d               2      NA
# 15 h               2      NA
# 16 i               2      NA
# 17 p               2       3
# 18 r               2      NA
# 19 21.11           1      NA
# 20 5.94            1      NA
# 21 is None         1      NA
# 22 l               1       1
# 23 t               1      NA

# %% [markdown]
# **Does missing have a pattern?**

# %%
# Lets see an upset plot of train
gg_miss_upset(train, text.scale = 2, number.angles = 45, nsets=5)
# Out:
# plot without title

# %% [markdown]
# **Systematic missingness:**
#
# The high correlation in missingness among the top five variables suggests a systematic reason for this data being absent. It could be due to data collection methods? certain types of mushrooms being harder to classify? or specific study designs.

# %% [markdown]
# **Does missing data have any pattern with the Class?**

# %%
train_bool <- train %>% 
  mutate_at(vars(all_of(features)), function(x) is.na(x))

relevant_feats_missing <- train_bool %>% 
  select(all_of(features)) %>% 
  summarise_all(sum) %>% 
  pivot_longer(cols = everything(), names_to = "feature", values_to = "is_missing") %>%
  filter(is_missing > 5) %>% pull(feature)

results <- train_bool %>%
  select(id, class, all_of(relevant_feats_missing)) %>%
  gather(features, is_missing, all_of(relevant_feats_missing)) %>%
  group_by(features, is_missing) %>%
  # Calculate the proportion of poisonous mushrooms between missing and non missing values
  summarize(total = n(),
    poisonous = sum(class == "p"),
    prop_poisonous = poisonous / total,
    .groups = "drop")  %>% 
  group_by(features) %>%
  # Calculate the difference in proportion of poisonous mushrooms between missing and non missing values
  mutate(baseline = prop_poisonous[!is_missing], 
    abs_diff_from_baseline = abs(prop_poisonous - baseline)) %>% # absolute difference
  filter(is_missing) %>%  # Keep only the rows where is_missing is TRUE
  ungroup() %>%
  arrange(desc(abs(abs_diff_from_baseline)))  # Sort by absolute difference

# %%
options(repr.plot.width=16, repr.plot.height=10)
results %>% 
  ggplot(aes(x = reorder(features, abs_diff_from_baseline), y = abs_diff_from_baseline, fill = abs_diff_from_baseline)) +
  geom_bar(stat = "identity", position = "dodge") +
  ylab("Absolute % difference") + xlab("") +
  scale_fill_gradient(low = "#FFCCCC", high = "#990000") +
  ggtitle("Absolute % difference in poisonous mushrooms between missing and non missing values") +
  coord_flip() +
  my_theme() +
  theme(legend.position = "none")
# Out:
# plot without title

# %% [markdown]
# Missing data is relevant:
#
# - `cap_color` has almost 30% difference between missing and non missing values.
# - `veil_color`and `has_ring` have barely any difference with respect non missing values.
#
# This information is relevant when imputing, missing could be category of its own in high missing features.

# %% [markdown]
# ### **Distribution of numeric Variables**

# %%
num_features <- train %>% 
  select_if(is.numeric) %>% 
  select(-id) %>% colnames()

df_dist <- train %>% 
  select(all_of(num_features)) %>% 
  mutate(type = "train") %>% 
  bind_rows(test %>% # adding test data to compare
              select_if(is.numeric) %>% 
              mutate(type = "test")) %>% 
    pivot_longer(cols = cap_diameter:stem_width, names_to = "features", values_to = "values")

# See distribution
# There is a extreme value in test cap_diameter
df_dist %>% 
  group_by(type, features) %>% 
  summarise(min = min(values, na.rm = TRUE),
            p25 = quantile(values, 0.25, na.rm = TRUE),
            p50 = quantile(values, 0.50, na.rm = TRUE),
            mean = mean(values, na.rm = TRUE),
            p75 = quantile(values, 0.75, na.rm = TRUE),
            max = max(values, na.rm = TRUE)) %>% 
  ungroup() %>% 
  arrange(features)
# Out:
# `summarise()` has grouped output by 'type'. You can override using the
# `.groups` argument.
#   type  features     min  p25  p50  mean      p75   max
# 1 test  cap_diameter 0.00 3.31 5.74  6.306192  8.23 607.00
# 2 train cap_diameter 0.03 3.32 5.75  6.309848  8.24  80.67
# 3 test  stem_height  0.00 4.67 5.88  6.346509  7.41  57.29
# 4 train stem_height  0.00 4.67 5.88  6.348333  7.41  88.72
# 5 test  stem_width   0.00 4.97 9.64 11.148374 15.62 102.91
# 6 train stem_width   0.00 4.97 9.65 11.153785 15.63 102.90

# %%
# Train and test distribution of numeric variables are identical
df_dist %>% 
  group_by(type, features) %>% 
  # Remove extreme ouliers
  filter(values < quantile(values, 0.99, na.rm = TRUE)) %>% 
  ungroup() %>% 
  ggplot(aes(x = type, y = values, fill = type)) +
  geom_boxplot() +
  facet_wrap(~features, ncol=3) +
  my_theme()
# Out:
# plot without title

# %% [markdown]
# Main ideas:
#
# - The distribution between train and test set of the numerical variables are identical.
# - The distributions are slightly negatively skewed (to the right).
# - The data shows outliers, however `cap_diameter` has a extreme outlier.

# %% [markdown]
# ### **Categorical Variables Exploration**

# %% [markdown]
# There seems to be a lot of values for each categorical features. I will analyze this by counting each value within a feature, and classifying each value into three types:
#
# - Mayority Values that account for the 90% of the Feature.
# - Minority that account for almost the 10% remaining.
# - Rare that account for les than 0.1%

# %%
cat_features <- train %>% 
  select_if(is.character) %>% 
  select(-class) %>% colnames()

cat_counts <- train %>% # If you want to explot test set change dataset here
  select(all_of(cat_features)) %>% 
  pivot_longer(everything(), names_to = "features", values_to = "values") %>%
  group_by(features, values) %>% 
  summarise(n = n()) %>%
  filter(!is.na(values)) %>% # remove NA values from each feature
  arrange(desc(n)) %>% 
  mutate(pct = n/sum(n),
         cum_pct = cumsum(pct),
         type = case_when(
           pct > 0.05 ~ "Majority",
           between(pct, 0.001, 0.05) ~ "Minority",
           TRUE ~ "Rare"
         ))
# Out:
# `summarise()` has grouped output by 'features'. You can override using the
# `.groups` argument.

# %%
# Lets see all the categorical variables
cat_counts %>% 
  count(features, type) %>% 
  ggplot(aes(x = type, y = n, fill = type)) +
  geom_bar(stat = "identity") +
  geom_text(aes(label = n), vjust = -0.5) +
  facet_wrap(~features, ncol = 3) +
  my_theme() + ylim(c(0,80)) +
  xlab("") + ylab("Counts")
# Out:
# plot without title

# %%
# Example of rare values for cap_surface
cat_counts %>% 
    filter(features == "cap_surface" ) # explore other features
# Out:
#    features    values               n      pct             cum_pct   type
# 1  cap_surface t                    460777 0.1883858111583 0.1883858 Majority
# 2  cap_surface s                    384970 0.1573925906059 0.3457784 Majority
# 3  cap_surface y                    327826 0.1340296215497 0.4798080 Majority
# 4  cap_surface h                    284460 0.1162997021164 0.5961077 Majority
# 5  cap_surface g                    263729 0.1078239616799 0.7039317 Majority
# 6  cap_surface d                    206832 0.0845619770377 0.7884937 Majority
# 7  cap_surface k                    128875 0.0526897423548 0.8411834 Majority
# 8  cap_surface e                    119712 0.0489435067839 0.8901269 Minority
# 9  cap_surface i                    113440 0.0463792385857 0.9365062 Minority
# 10 cap_surface w                    109840 0.0449074009719 0.9814136 Minority
# 11 cap_surface l                     44859 0.0183403231992 0.9997539 Minority
# 12 cap_surface n                        96 0.0000392490030 0.9997931 Rare
# 13 cap_surface f                        75 0.0000306632836 0.9998238 Rare
# 14 cap_surface p                        59 0.0000241217831 0.9998479 Rare
# 15 cap_surface u                        49 0.0000200333453 0.9998679 Rare
# 16 cap_surface a                        44 0.0000179891264 0.9998859 Rare
# 17 cap_surface m                        42 0.0000171714388 0.9999031 Rare
# 18 cap_surface o                        39 0.0000159449075 0.9999190 Rare
# 19 cap_surface r                        35 0.0000143095324 0.9999334 Rare
# 20 cap_surface x                        33 0.0000134918448 0.9999469 Rare
# 21 cap_surface c                        31 0.0000126741572 0.9999595 Rare
# 22 cap_surface b                        18 0.0000073591881 0.9999669 Rare
# 23 cap_surface z                         8 0.0000032707503 0.9999702 Rare
# 24 cap_surface season                    7 0.0000028619065 0.9999730 Rare
# 25 cap_surface ring-type                 4 0.0000016353751 0.9999747 Rare
# 26 cap_surface class                     2 0.0000008176876 0.9999755 Rare
# 27 cap_surface does None                 2 0.0000008176876 0.9999763 Rare
# 28 cap_surface does t                    2 0.0000008176876 0.9999771 Rare
# 29 cap_surface has-ring                  2 0.0000008176876 0.9999779 Rare
# 30 cap_surface 0.85                      1 0.0000004088438 0.9999783 Rare
# ?  ?           ?                    ?      ?               ?         ?
# 54 cap_surface 3.06                 1      0.0000004088438 0.9999881 Rare
# 55 cap_surface 3.33                 1      0.0000004088438 0.9999886 Rare
# 56 cap_surface 3.64                 1      0.0000004088438 0.9999890 Rare
# 57 cap_surface 4.21                 1      0.0000004088438 0.9999894 Rare
# 58 cap_surface 4.66                 1      0.0000004088438 0.9999898 Rare
# 59 cap_surface 4.93                 1      0.0000004088438 0.9999902 Rare
# 60 cap_surface 41.91                1      0.0000004088438 0.9999906 Rare
# 61 cap_surface 5.07                 1      0.0000004088438 0.9999910 Rare
# 62 cap_surface 5.73                 1      0.0000004088438 0.9999914 Rare
# 63 cap_surface 6.45                 1      0.0000004088438 0.9999918 Rare
# 64 cap_surface 6.49                 1      0.0000004088438 0.9999922 Rare
# 65 cap_surface 6.57                 1      0.0000004088438 0.9999926 Rare
# 66 cap_surface 7.14                 1      0.0000004088438 0.9999930 Rare
# 67 cap_surface 7.99                 1      0.0000004088438 0.9999935 Rare
# 68 cap_surface 8.01                 1      0.0000004088438 0.9999939 Rare
# 69 cap_surface 8.1                  1      0.0000004088438 0.9999943 Rare
# 70 cap_surface 8.96                 1      0.0000004088438 0.9999947 Rare
# 71 cap_surface 9.22                 1      0.0000004088438 0.9999951 Rare
# 72 cap_surface cap-diameter         1      0.0000004088438 0.9999955 Rare
# 73 cap_surface does h               1      0.0000004088438 0.9999959 Rare
# 74 cap_surface does l               1      0.0000004088438 0.9999963 Rare
# 75 cap_surface does-bruise-or-bleed 1      0.0000004088438 0.9999967 Rare
# 76 cap_surface has h                1      0.0000004088438 0.9999971 Rare
# 77 cap_surface is None              1      0.0000004088438 0.9999975 Rare
# 78 cap_surface is h                 1      0.0000004088438 0.9999980 Rare
# 79 cap_surface is k                 1      0.0000004088438 0.9999984 Rare
# 80 cap_surface is y                 1      0.0000004088438 0.9999988 Rare
# 81 cap_surface spore-color          1      0.0000004088438 0.9999992 Rare
# 82 cap_surface spore-print-color    1      0.0000004088438 0.9999996 Rare
# 83 cap_surface veil-color           1      0.0000004088438 1.0000000 Rare

# %% [markdown]
# Important findings:
#
# - `Rare` types make of the mayority of the unique values for almost all of the categorical features.
# - `Rare` types usually have less than 100 values. (Check other features above)
# - `cap_surface`, `habitat` and `cap_shape` have around 70 unique rare values.
# - Many of the rare values in cap_surface is just **garbage or noise**

# %% [markdown]
# **Does the original dataset have this rare values?**

# %%
# install.packages("ucimlrepo")
library(ucimlrepo)

# Fetch the Mushroom dataset
mushroom_data <- ucimlrepo::fetch_ucirepo(id = 848)
original_data <- mushroom_data$data$original %>% as_tibble() 

# Correct column names 
col_names <- colnames(original_data)
col_names <- gsub("-", "_", col_names)
colnames(original_data) <- col_names

# %% [markdown]
# Comparing to the original dataset, most of the unique variables seen in train were just created, the original dataset doesn't have this rare values.

# %%
original_data %>% count(cap_surface, sort = TRUE)
# Out:
#    cap_surface n
# 1  NaN         14120
# 2  t            8196
# 3  s            7608
# 4  y            6341
# 5  h            4974
# 6  g            4724
# 7  d            4432
# 8  e            2584
# 9  k            2303
# 10 i            2225
# 11 w            2150
# 12 l            1412

# %% [markdown]
# **Is this true for test set?**

# %%
train_test_count <- train %>% 
  select(-class) %>%
  mutate(split = "train") %>%
  # adding test set to the mix
  bind_rows(test %>% mutate(split = "test"))  %>% 
  select(all_of(cat_features), split) %>% 
  pivot_longer(cols = -split, names_to = "features", values_to = "values")  %>%
  group_by(split, features, values) %>% 
  summarise(n = n()) %>%
  filter(!is.na(values)) %>% # remove NA values from each feature
  arrange(desc(n)) %>% 
  mutate(pct = n/sum(n),
         type = case_when(
           pct > 0.05 ~ "Majority",
           pct >= 0.001 ~ "Minority",
           TRUE ~ "Rare"
         )) 
  
  train_test_count  %>% 
  count(features, type)  %>% 
  pivot_wider(names_from = features, values_from = n)  %>% 
  arrange(type, split)
# Out:
# `summarise()` has grouped output by 'split', 'features'. You can override using
# the `.groups` argument.
#   split type     cap_color cap_shape cap_surface gill_attachment gill_color
# 1 test  Majority  6         4         7           6               6
# 2 train Majority  6         4         7           6               6
# 3 test  Minority  6         3         4           1               6
# 4 train Minority  6         3         4           1               6
# 5 test  Rare     45        55        48          59              44
# 6 train Rare     66        67        72          71              51
#   gill_spacing habitat ring_type season spore_print_color stem_color stem_root
# 1  3            3       1         3      4                 3          4
# 2  3            3       1         3      4                 3          4
# 3 NA            5       7         1      3                 9          1
# 4 NA            5       7         1      3                 9          1
# 5 32           31      28        NA     26                43         26
# 6 45           44      32        NA     25                47         33
#   stem_surface veil_color veil_type
# 1  6            3          1
# 2  6            3          1
# 3  1            3         NA
# 4  1            3         NA
# 5 47           17         14
# 6 53           18         21

# %%
# Comparing train and test set majority features
train_test_count %>% 
    filter(type == "Minority", # change here to see other types
    features == "habitat") %>% # change here to see other features
    select(split, features, values, pct) %>%
    pivot_wider(names_from = split, values_from = pct)
# Out:
#   features values train       test
# 1 habitat  m      0.048435625 0.048730016
# 2 habitat  h      0.038543745 0.038515086
# 3 habitat  w      0.005945009 0.005930877
# 4 habitat  p      0.005511887 0.005500161
# 5 habitat  u      0.001688858 0.001652599

# %% [markdown]
# For test set:
#
# - The majority features are identical between train and test set (explore above).
# - The minority features are identical too.
# - The rar features are different (noise)

# %% [markdown]
# **Does these rare values have any predictive power?**
#
# Lets calculate chi-square statistic and Cramers'V for feature.

# %%
# Step 1: Create encoding function
encode_categories <- function(data) {
  data %>%
    group_by(features, values) %>%
    summarise(count = n(), .groups = "drop") %>%
    group_by(features) %>%
    mutate(
      total = sum(count),
      prevalence = count / total,
      type = case_when(
        prevalence > 0.05 ~ "Majority",
        prevalence > 0.001 ~ "Minority",
        TRUE ~ "Rare"
      )
    ) %>%
    select(features, values, count, type)
}

# Step 2: Create long dataset in train for categorical variables 
train_long <- train %>% 
    select(class, all_of(cat_features))  %>% 
    pivot_longer(cols = -class, names_to = "features", values_to = "values") %>% 
    filter(!is.na(values)) 

# Step 3: Apply encoding
encoded_categories <- train_long %>%
  encode_categories()

# Step 4: Join encoded categories with original data
encoded_data <- train_long %>%
  left_join(encoded_categories, by = c("features", "values"))

# %%
# Identify Features_Types with only 1 categorical variable
# The statistical test to follow can't handle 1 value of a categorical variable
remove_feature_types <- cat_counts %>% 
  count(features, type)  %>% 
  filter(n == 1) %>% 
  unite("features_type", features, type, sep = "_") %>% pull(features_type)

# %%
# Step 5: Apply Chi-Square test to identify relationship between categorical variables # nolint
# Cramers V is a measure of association between two categorical variables
# Lowering sample size avoids over-signficance of chi-squared test
set.seed(40)
encoded_data %>%
  unite("features_type", features, type, sep = "_") %>%
  filter(!features_type %in% remove_feature_types) %>% 
  sample_n(5e6) %>% 
  group_by(features_type) %>%
  summarise(
    chi_square = chisq.test(table(values, class))$statistic, # Is there a relationship between the two categorical variables?
    p_value = round(chisq.test(table(values, class))$p.value, 4), # How likely is the relationship due to chance?
    significant = p_value < 0.05,
    cramers_v = cramers_v(table(values, class))$Cramers_v, # How strong is the relationship? 0 to 1
    .groups = "drop") %>%
  mutate(interpretation = case_when(cramers_v < 0.10 ~ "Negligible association",
                                    cramers_v < 0.20 ~ "Weak association",
                                    cramers_v < 0.40 ~ "Moderate association",
                                    cramers_v < 0.60 ~ "Relatively strong association",
                                    cramers_v < 0.80 ~ "Strong association",
                                    cramers_v <= 1.00 ~ "Very strong association",
                                    TRUE ~ "Invalid Cramer's V")) %>%
  arrange(desc(cramers_v))
# Out:
# Warning message:
# "There were 30 warnings in `summarise()`.
# The first warning was:
# i In argument: `chi_square = chisq.test(table(values, class))$statistic`.
# i In group 3: `features_type = "cap_color_Rare"`.
# Caused by warning in `chisq.test()`:
# ! Chi-squared approximation may be incorrect
# i Run `dplyr::last_dplyr_warnings()` to see the 29 remaining warnings."
#    features_type              chi_square  p_value significant cramers_v
# 1  spore_print_color_Minority  3176.10285 0.0000   TRUE       0.97353799
# 2  stem_surface_Rare             81.90757 0.0000   TRUE       0.62021377
# 3  stem_color_Rare               62.61425 0.0000   TRUE       0.57839735
# 4  stem_root_Majority         17487.24299 0.0000   TRUE       0.52114437
# 5  cap_color_Minority         16557.34433 0.0000   TRUE       0.47946229
# 6  ring_type_Minority         20711.94642 0.0000   TRUE       0.47593834
# 7  veil_color_Majority        10612.43072 0.0000   TRUE       0.41749091
# 8  habitat_Minority            8908.60535 0.0000   TRUE       0.40061154
# 9  veil_type_Rare                11.98264 0.2143  FALSE       0.38968173
# 10 cap_shape_Rare                38.19750 0.0442   TRUE       0.36342680
# 11 spore_print_color_Majority  5816.88461 0.0000   TRUE       0.36089902
# 12 stem_color_Minority        12672.42311 0.0000   TRUE       0.36065999
# 13 stem_surface_Majority      22422.01951 0.0000   TRUE       0.33651683
# 14 habitat_Rare                  24.91340 0.1273  FALSE       0.33471997
# 15 veil_color_Rare               14.03509 0.2311  FALSE       0.32795043
# 16 cap_surface_Minority        6709.14486 0.0000   TRUE       0.31096175
# 17 cap_surface_Majority       27257.99062 0.0000   TRUE       0.27224430
# 18 gill_attachment_Majority   26230.99614 0.0000   TRUE       0.24354335
# 19 gill_color_Minority         4724.18863 0.0000   TRUE       0.24018969
# 20 gill_spacing_Rare             12.84801 0.3034  FALSE       0.23427839
# 21 stem_color_Majority        22868.03029 0.0000   TRUE       0.22311862
# 22 ring_type_Rare                19.44292 0.2464  FALSE       0.22023524
# 23 gill_color_Majority        21751.73441 0.0000   TRUE       0.21390520
# 24 cap_color_Majority         20224.77222 0.0000   TRUE       0.20418338
# 25 cap_shape_Minority          1975.23429 0.0000   TRUE       0.18621967
# 26 gill_color_Rare               19.39091 0.3066  FALSE       0.17091067
# 27 gill_attachment_Rare          28.82279 0.3192  FALSE       0.16780341
# 28 cap_shape_Majority         13921.43637 0.0000   TRUE       0.16690529
# 29 cap_surface_Rare              30.02987 0.3128  FALSE       0.15467920
# 30 gill_spacing_Majority       6518.86195 0.0000   TRUE       0.13991291
# 31 season_Majority             9689.93147 0.0000   TRUE       0.13490838
# 32 habitat_Majority            8590.38352 0.0000   TRUE       0.13070110
# 33 stem_root_Rare                16.87004 0.3941  FALSE       0.10879278
# 34 veil_color_Minority           12.18375 0.0023   TRUE       0.03982409
# 35 cap_color_Rare                21.75214 0.4748  FALSE       0.00000000
# 36 spore_print_color_Rare        10.50000 0.5722  FALSE       0.00000000
#    interpretation
# 1  Very strong association
# 2  Strong association
# 3  Relatively strong association
# 4  Relatively strong association
# 5  Relatively strong association
# 6  Relatively strong association
# 7  Relatively strong association
# 8  Relatively strong association
# 9  Moderate association
# 10 Moderate association
# 11 Moderate association
# 12 Moderate association
# 13 Moderate association
# 14 Moderate association
# 15 Moderate association
# 16 Moderate association
# 17 Moderate association
# 18 Moderate association
# 19 Moderate association
# 20 Moderate association
# 21 Moderate association
# 22 Moderate association
# 23 Moderate association
# 24 Moderate association
# 25 Weak association
# 26 Weak association
# 27 Weak association
# 28 Weak association
# 29 Weak association
# 30 Weak association
# 31 Weak association
# 32 Weak association
# 33 Weak association
# 34 Negligible association
# 35 Negligible association
# 36 Negligible association

# %% [markdown]
# Main ideas:
#
# - Most of the groupings by feature are relevant by chi-squared statistic, however this is expected due to the large sample size.
# - Cramers'V comes to the rescue which focuses on the effect size, some of the rare groupings are signficant and have strong association.
# - Some rare groupings relevant to notice are `stem_color_Rare`, `stem_surface_Rare`, `veil_color_Rare`.
# - The rest of the rare grouping are not significant or relevant from cramers'V View.

# %%
# Lets check with information value and weight of evidence
iv_data <- encoded_data %>%
    filter(type == "Rare") %>%
    unite("features_type", features, type, sep = "_")  %>% 
    count(features_type, class)  %>% 
    pivot_wider(names_from = class, values_from = n)   %>% 
    mutate(prop_p = p / (p + e), # proportion of poisonous mushrooms
           prop_e = e / (p + e), # proportion of edible mushrooms
           woe = log(prop_e / prop_p), # weight of evidence
           inf_value = (prop_e - prop_p) * woe)  %>% # information value
    arrange(desc(inf_value))  %>% 
    mutate(iv_interpretation = case_when(inf_value < 0.02 ~ "Unpredictive",
                                          inf_value < 0.1 ~ "Weak predictive power",
                                          inf_value < 0.3 ~ "Moderate predictive power",
                                          inf_value < 0.5 ~ "Strong predictive power",
                                          inf_value >= 0.5 ~ "Extremely strong predictive power",
                                          TRUE ~ "Suspicious (potential overfitting)"))

iv_data %>% 
       ggplot(aes(x = reorder(features_type, inf_value), y = inf_value, fill = iv_interpretation)) +
       geom_bar(stat = "identity") +
       coord_flip() +
       xlab("") + ylab("Information Value") +
       ggtitle("Information Value of Rare Categorical Variables") +
       my_theme()
# Out:
# plot without title

# %% [markdown]
# Information value on the rare groupings confirm what we did above that `stem_color_Rare`, `stem_surface_Rare`, `veil_color_Rare` are relevant to the problem. So in the end its **not recommendable to through away rare values at least for these features.**

# %% [markdown]
# **Does test set have the same rare types?**

# %%
# Rare types are different between train and test set
train %>% 
  count(stem_color) %>% 
  arrange(desc(n)) %>% 
  full_join(test %>% count(stem_color), by = "stem_color")
# Out:
#    stem_color           n.x     n.y
# 1  w                    1196637 797365
# 2  n                    1003464 668156
# 3  y                     373971 250141
# 4  g                     132019  88202
# 5  o                     111541  75094
# 6  e                     103373  68804
# 7  u                      67017  44784
# 8  p                      54690  36356
# 9  k                      33676  22176
# 10 r                      22329  14910
# 11 l                       9994   6518
# 12 b                       7365   4895
# 13 f                        573    355
# 14 s                         51     35
# 15 t                         40     21
# 16 NA                        38     21
# 17 a                         36     21
# 18 x                         20     17
# 19 i                         19     21
# 20 d                         16     12
# 21 h                         12     12
# 22 m                         11      3
# 23 c                          7      8
# 24 z                          6      3
# 25 ring-type                  3      1
# 26 class                      2      1
# 27 spore-print-color          2      3
# 28 1.41                       1     NA
# 29 1.75                       1     NA
# 30 12.92                      1     NA
# ?  ?                    ?       ?
# 60 is w                  1      NA
# 61 10.6                 NA       1
# 62 10.93                NA       1
# 63 11.0                 NA       1
# 64 11.31                NA       1
# 65 17.16                NA       1
# 66 17.49                NA       1
# 67 2.84                 NA       1
# 68 2.96                 NA       1
# 69 3.02                 NA       1
# 70 3.05                 NA       1
# 71 3.66                 NA       1
# 72 3.8                  NA       1
# 73 5.5                  NA       1
# 74 5.61                 NA       1
# 75 6.28                 NA       1
# 76 6.58                 NA       1
# 77 6.67                 NA       1
# 78 6.93                 NA       1
# 79 6.99                 NA       1
# 80 7.35                 NA       1
# 81 7.71                 NA       1
# 82 8.04                 NA       1
# 83 8.09                 NA       1
# 84 does-bruise-or-bleed NA       1
# 85 habitat              NA       1
# 86 season               NA       1
# 87 stem-root            NA       1
# 88 veil-color           NA       1
# 89 veil-type            NA       1

# %% [markdown]
# # **Collapsing categorical variables**

# %% [markdown]
# I will collapse rare values to a placeholder called `rare` as I did above using a prevalence of 0.1%, this criteria will apply for test set too.

# %%
cat_features <- train %>% 
  select_if(is.character) %>% 
  select(-class) %>% colnames()

# Step 1: Create a function to identify rare categories
identify_rare_categories <- function(data, feature, threshold = 0.001) {
  data %>%
    count(!!sym(feature)) %>%
    mutate(
      total = sum(n),
      prevalence = n / total) %>%
    filter(prevalence >= threshold) %>%
    pull(!!sym(feature))
}

# Step 2: Create a function to replace rare categories with "rare"
replace_rare_categories <- function(data, feature, threshold = 0.001) {
  non_rare <- identify_rare_categories(data, feature, threshold)
  data %>%
    mutate(!!sym(feature) := if_else(!!sym(feature) %in% non_rare, 
                                     !!sym(feature), 
                                     "rare"))
}

# Step 3: Apply the transformation to all categorical variables in the training set
# The reduce function in Step 3 Applies the replace_rare_categories function to each categorical feature in turn
# The result is a dataset where all rare categories (prevalence < 0.001) in all categorical variables have been replaced with "Rare"
train_collapsed <- cat_features %>%
  reduce(function(data, feature) replace_rare_categories(data, feature), .init = train)

# Step 4: Apply the transformation to all categorical variables in the test set
test_collapsed <- cat_features %>%
  reduce(function(data, feature) replace_rare_categories(data, feature), .init = test)

# Lets check if the rare values are now "rare"
train_collapsed %>% 
  count(stem_color) %>% 
  arrange(desc(n)) %>% 
  full_join(test_collapsed %>% count(stem_color), by = "stem_color")
# Out:
#    stem_color n.x     n.y
# 1  w          1196637 797365
# 2  n          1003464 668156
# 3  y           373971 250141
# 4  g           132019  88202
# 5  o           111541  75094
# 6  e           103373  68804
# 7  u            67017  44784
# 8  p            54690  36356
# 9  k            33676  22176
# 10 r            22329  14910
# 11 l             9994   6518
# 12 b             7365   4895
# 13 rare           869    563

# %% [markdown]
# # **Imputing missing values**

# %% [markdown]
# In this first submission I will just create a `Missing` category for categorical variables and for numerical variables impute the median. For logical columns will convert them to integer.

# %%
impute_missing <- function(data) {
  # Identify numeric and categorical columns
  num_cols <- data %>% select_if(is.numeric) %>% names()
  cat_cols <- data %>% select_if(is.character) %>% names()
  
  # Calculate median for numeric columns
  medians <- data %>% summarise(across(all_of(num_cols), ~median(.x, na.rm = TRUE)))
  
  # Impute missing values
  data %>%
    mutate(across(all_of(num_cols), ~replace_na(.x, medians[[cur_column()]]))) %>%
    mutate(across(all_of(cat_cols), ~replace_na(.x, "Missing")))
}

# Apply to train data
train_imputed <- train_collapsed %>% 
  mutate_if(is.logical, as.integer) %>%
  impute_missing()

# Apply to test data
test_imputed <- test_collapsed %>% 
  mutate_if(is.logical, as.integer) %>%
  impute_missing()

# %%
# Example of veil type for train and test 
train_imputed %>% 
    count(veil_type) %>% 
    left_join(test_imputed %>% count(veil_type), by = "veil_type", suffix = c("_train", "_test"))
# Out:
#   veil_type n_train n_test
# 1 Missing   2957493 1971545
# 2 rare           79      46
# 3 u          159373  106373

# %% [markdown]
# # **Modeling with TidyModels**

# %%
# Lets start creating our recipe 
train_data <- train_imputed %>% 
  mutate(class = as.factor(as.integer(class == 'p'))) %>%
  mutate_if(is.character, as.factor) %>% 
  sample_n(1e6)

# %%
# 1. Create the two recipes
recipe_no_encoding <- recipe(class ~ ., data = train_data) %>%
  step_rm(id) %>%
  step_normalize(all_numeric_predictors()) %>%
  step_zv(all_predictors())

recipe_effect_encoding <- recipe_no_encoding %>%
  step_lencode_mixed(all_nominal_predictors(), outcome = vars(class))

# %%
# 2. Define the LightGBM model with tunable parameters
lightgbm_model <- boost_tree(
  trees = tune(),
  tree_depth = tune(),
  min_n = tune(),
  loss_reduction = tune(),
  sample_size = tune(),
  mtry = tune(),
  learn_rate = tune()
) %>%
  set_engine("lightgbm") %>%
  set_mode("classification")

# %%
# 3. Create a workflow set
workflow_set <- workflow_set(
  preproc = list(no_encoding = recipe_no_encoding,
                 effect_encoding = recipe_effect_encoding),
  models = list(lightgbm = lightgbm_model),
  cross = TRUE
)

# %%
# 4. Define the resampling method
cv_folds <- vfold_cv(train_data, v = 5, strata = class)

# 5. Define the tuning grid
tuning_grid <- grid_latin_hypercube(
  trees(range = c(100, 1000)),
  tree_depth(range = c(3, 10)),
  min_n(range = c(5, 30)),
  loss_reduction(range = c(-10, 1.5), trans = log10_trans()),
  sample_size = sample_prop(range = c(0.4, 1.0)),
  finalize(mtry(), train_data),
  learn_rate(range = c(-5, -0.5), trans = log10_trans()),
  size = 30
)

# 6. Define metrics
metrics <- metric_set(roc_auc, mcc)

# %%
# Set up parallel processing
#cores <- parallel::detectCores() - 2  # Use all cores except one
#cl <- makeCluster(cores)
#registerDoParallel(cl)

# %%
# 7. Tune the workflows using Bayesian optimization with parallel processing
tuning_results <- workflow_set %>%
  workflow_map(
    resamples = cv_folds,
    grid = tuning_grid,
    metrics = metrics,
    control = control_bayes(
      no_improve = 10,
      time_limit = 3600,
      verbose = TRUE
    )
  )
  #stopCluster(cl)
# Out:
# i Fold1: preprocessor 1/1
#
# v Fold1: preprocessor 1/1
#
# i Fold1: preprocessor 1/1, model 1/30
#
# v Fold1: preprocessor 1/1, model 1/30
#
# i Fold1: preprocessor 1/1, model 1/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 1/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 2/30
#
# v Fold1: preprocessor 1/1, model 2/30
#
# i Fold1: preprocessor 1/1, model 2/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 2/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 3/30
#
# v Fold1: preprocessor 1/1, model 3/30
#
# i Fold1: preprocessor 1/1, model 3/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 3/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 4/30
#
# v Fold1: preprocessor 1/1, model 4/30
#
# i Fold1: preprocessor 1/1, model 4/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 4/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 5/30
#
# v Fold1: preprocessor 1/1, model 5/30
#
# i Fold1: preprocessor 1/1, model 5/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 5/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 6/30
#
# v Fold1: preprocessor 1/1, model 6/30
#
# i Fold1: preprocessor 1/1, model 6/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 6/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 7/30
#
# x Fold1: preprocessor 1/1, model 7/30:
#   Error in data$construct(): Check failed: (feature_fraction_bynode) <= ...
#
#
# i Fold1: preprocessor 1/1, model 8/30
#
# v Fold1: preprocessor 1/1, model 8/30
#
# i Fold1: preprocessor 1/1, model 8/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 8/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 9/30
#
# x Fold1: preprocessor 1/1, model 9/30:
#   Error in data$construct(): Check failed: (feature_fraction_bynode) <= ...
#
#
# i Fold1: preprocessor 1/1, model 10/30
#
# v Fold1: preprocessor 1/1, model 10/30
#
# i Fold1: preprocessor 1/1, model 10/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 10/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 11/30
#
# v Fold1: preprocessor 1/1, model 11/30
#
# i Fold1: preprocessor 1/1, model 11/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 11/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 12/30
#
# v Fold1: preprocessor 1/1, model 12/30
#
# i Fold1: preprocessor 1/1, model 12/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 12/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 13/30
#
# v Fold1: preprocessor 1/1, model 13/30
#
# i Fold1: preprocessor 1/1, model 13/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 13/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 14/30
#
# v Fold1: preprocessor 1/1, model 14/30
#
# i Fold1: preprocessor 1/1, model 14/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 14/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 15/30
#
# v Fold1: preprocessor 1/1, model 15/30
#
# i Fold1: preprocessor 1/1, model 15/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 15/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 16/30
#
# v Fold1: preprocessor 1/1, model 16/30
#
# i Fold1: preprocessor 1/1, model 16/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 16/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 17/30
#
# v Fold1: preprocessor 1/1, model 17/30
#
# i Fold1: preprocessor 1/1, model 17/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 17/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 18/30
#
# v Fold1: preprocessor 1/1, model 18/30
#
# i Fold1: preprocessor 1/1, model 18/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 18/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 19/30
#
# v Fold1: preprocessor 1/1, model 19/30
#
# i Fold1: preprocessor 1/1, model 19/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 19/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 20/30
#
# v Fold1: preprocessor 1/1, model 20/30
#
# i Fold1: preprocessor 1/1, model 20/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 20/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 21/30
#
# v Fold1: preprocessor 1/1, model 21/30
#
# i Fold1: preprocessor 1/1, model 21/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 21/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 22/30
#
# v Fold1: preprocessor 1/1, model 22/30
#
# i Fold1: preprocessor 1/1, model 22/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 22/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 23/30
#
# v Fold1: preprocessor 1/1, model 23/30
#
# i Fold1: preprocessor 1/1, model 23/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 23/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 24/30
#
# v Fold1: preprocessor 1/1, model 24/30
#
# i Fold1: preprocessor 1/1, model 24/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 24/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 25/30
#
# v Fold1: preprocessor 1/1, model 25/30
#
# i Fold1: preprocessor 1/1, model 25/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 25/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 26/30
#
# v Fold1: preprocessor 1/1, model 26/30
#
# i Fold1: preprocessor 1/1, model 26/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 26/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 27/30
#
# v Fold1: preprocessor 1/1, model 27/30
#
# i Fold1: preprocessor 1/1, model 27/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 27/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 28/30
#
# v Fold1: preprocessor 1/1, model 28/30
#
# i Fold1: preprocessor 1/1, model 28/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 28/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 29/30
#
# v Fold1: preprocessor 1/1, model 29/30
#
# i Fold1: preprocessor 1/1, model 29/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 29/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 30/30
#
# v Fold1: preprocessor 1/1, model 30/30
#
# i Fold1: preprocessor 1/1, model 30/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 30/30 (predictions)
#
# i Fold2: preprocessor 1/1
#
# v Fold2: preprocessor 1/1
#
# i Fold2: preprocessor 1/1, model 1/30
#
# v Fold2: preprocessor 1/1, model 1/30
#
# i Fold2: preprocessor 1/1, model 1/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 1/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 2/30
#
# v Fold2: preprocessor 1/1, model 2/30
#
# i Fold2: preprocessor 1/1, model 2/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 2/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 3/30
#
# v Fold2: preprocessor 1/1, model 3/30
#
# i Fold2: preprocessor 1/1, model 3/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 3/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 4/30
#
# v Fold2: preprocessor 1/1, model 4/30
#
# i Fold2: preprocessor 1/1, model 4/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 4/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 5/30
#
# v Fold2: preprocessor 1/1, model 5/30
#
# i Fold2: preprocessor 1/1, model 5/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 5/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 6/30
#
# v Fold2: preprocessor 1/1, model 6/30
#
# i Fold2: preprocessor 1/1, model 6/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 6/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 7/30
#
# x Fold2: preprocessor 1/1, model 7/30:
#   Error in data$construct(): Check failed: (feature_fraction_bynode) <= ...
#
#
# i Fold2: preprocessor 1/1, model 8/30
#
# v Fold2: preprocessor 1/1, model 8/30
#
# i Fold2: preprocessor 1/1, model 8/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 8/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 9/30
#
# x Fold2: preprocessor 1/1, model 9/30:
#   Error in data$construct(): Check failed: (feature_fraction_bynode) <= ...
#
#
# i Fold2: preprocessor 1/1, model 10/30
#
# v Fold2: preprocessor 1/1, model 10/30
#
# i Fold2: preprocessor 1/1, model 10/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 10/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 11/30
#
# v Fold2: preprocessor 1/1, model 11/30
#
# i Fold2: preprocessor 1/1, model 11/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 11/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 12/30
#
# v Fold2: preprocessor 1/1, model 12/30
#
# i Fold2: preprocessor 1/1, model 12/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 12/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 13/30
#
# v Fold2: preprocessor 1/1, model 13/30
#
# i Fold2: preprocessor 1/1, model 13/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 13/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 14/30
#
# v Fold2: preprocessor 1/1, model 14/30
#
# i Fold2: preprocessor 1/1, model 14/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 14/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 15/30
#
# v Fold2: preprocessor 1/1, model 15/30
#
# i Fold2: preprocessor 1/1, model 15/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 15/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 16/30
#
# v Fold2: preprocessor 1/1, model 16/30
#
# i Fold2: preprocessor 1/1, model 16/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 16/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 17/30
#
# v Fold2: preprocessor 1/1, model 17/30
#
# i Fold2: preprocessor 1/1, model 17/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 17/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 18/30
#
# v Fold2: preprocessor 1/1, model 18/30
#
# i Fold2: preprocessor 1/1, model 18/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 18/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 19/30
#
# v Fold2: preprocessor 1/1, model 19/30
#
# i Fold2: preprocessor 1/1, model 19/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 19/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 20/30
#
# v Fold2: preprocessor 1/1, model 20/30
#
# i Fold2: preprocessor 1/1, model 20/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 20/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 21/30
#
# v Fold2: preprocessor 1/1, model 21/30
#
# i Fold2: preprocessor 1/1, model 21/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 21/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 22/30
#
# v Fold2: preprocessor 1/1, model 22/30
#
# i Fold2: preprocessor 1/1, model 22/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 22/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 23/30
#
# v Fold2: preprocessor 1/1, model 23/30
#
# i Fold2: preprocessor 1/1, model 23/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 23/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 24/30
#
# v Fold2: preprocessor 1/1, model 24/30
#
# i Fold2: preprocessor 1/1, model 24/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 24/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 25/30
#
# v Fold2: preprocessor 1/1, model 25/30
#
# i Fold2: preprocessor 1/1, model 25/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 25/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 26/30
#
# v Fold2: preprocessor 1/1, model 26/30
#
# i Fold2: preprocessor 1/1, model 26/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 26/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 27/30
#
# v Fold2: preprocessor 1/1, model 27/30
#
# i Fold2: preprocessor 1/1, model 27/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 27/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 28/30
#
# v Fold2: preprocessor 1/1, model 28/30
#
# i Fold2: preprocessor 1/1, model 28/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 28/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 29/30
#
# v Fold2: preprocessor 1/1, model 29/30
#
# i Fold2: preprocessor 1/1, model 29/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 29/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 30/30
#
# v Fold2: preprocessor 1/1, model 30/30
#
# i Fold2: preprocessor 1/1, model 30/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 30/30 (predictions)
#
# i Fold3: preprocessor 1/1
#
# v Fold3: preprocessor 1/1
#
# i Fold3: preprocessor 1/1, model 1/30
#
# v Fold3: preprocessor 1/1, model 1/30
#
# i Fold3: preprocessor 1/1, model 1/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 1/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 2/30
#
# v Fold3: preprocessor 1/1, model 2/30
#
# i Fold3: preprocessor 1/1, model 2/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 2/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 3/30
#
# v Fold3: preprocessor 1/1, model 3/30
#
# i Fold3: preprocessor 1/1, model 3/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 3/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 4/30
#
# v Fold3: preprocessor 1/1, model 4/30
#
# i Fold3: preprocessor 1/1, model 4/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 4/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 5/30
#
# v Fold3: preprocessor 1/1, model 5/30
#
# i Fold3: preprocessor 1/1, model 5/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 5/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 6/30
#
# v Fold3: preprocessor 1/1, model 6/30
#
# i Fold3: preprocessor 1/1, model 6/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 6/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 7/30
#
# x Fold3: preprocessor 1/1, model 7/30:
#   Error in data$construct(): Check failed: (feature_fraction_bynode) <= ...
#
#
# i Fold3: preprocessor 1/1, model 8/30
#
# v Fold3: preprocessor 1/1, model 8/30
#
# i Fold3: preprocessor 1/1, model 8/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 8/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 9/30
#
# x Fold3: preprocessor 1/1, model 9/30:
#   Error in data$construct(): Check failed: (feature_fraction_bynode) <= ...
#
#
# i Fold3: preprocessor 1/1, model 10/30
#
# v Fold3: preprocessor 1/1, model 10/30
#
# i Fold3: preprocessor 1/1, model 10/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 10/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 11/30
#
# v Fold3: preprocessor 1/1, model 11/30
#
# i Fold3: preprocessor 1/1, model 11/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 11/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 12/30
#
# v Fold3: preprocessor 1/1, model 12/30
#
# i Fold3: preprocessor 1/1, model 12/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 12/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 13/30
#
# v Fold3: preprocessor 1/1, model 13/30
#
# i Fold3: preprocessor 1/1, model 13/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 13/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 14/30
#
# v Fold3: preprocessor 1/1, model 14/30
#
# i Fold3: preprocessor 1/1, model 14/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 14/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 15/30
#
# v Fold3: preprocessor 1/1, model 15/30
#
# i Fold3: preprocessor 1/1, model 15/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 15/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 16/30
#
# v Fold3: preprocessor 1/1, model 16/30
#
# i Fold3: preprocessor 1/1, model 16/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 16/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 17/30
#
# v Fold3: preprocessor 1/1, model 17/30
#
# i Fold3: preprocessor 1/1, model 17/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 17/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 18/30
#
# v Fold3: preprocessor 1/1, model 18/30
#
# i Fold3: preprocessor 1/1, model 18/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 18/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 19/30
#
# v Fold3: preprocessor 1/1, model 19/30
#
# i Fold3: preprocessor 1/1, model 19/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 19/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 20/30
#
# v Fold3: preprocessor 1/1, model 20/30
#
# i Fold3: preprocessor 1/1, model 20/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 20/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 21/30
#
# v Fold3: preprocessor 1/1, model 21/30
#
# i Fold3: preprocessor 1/1, model 21/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 21/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 22/30
#
# v Fold3: preprocessor 1/1, model 22/30
#
# i Fold3: preprocessor 1/1, model 22/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 22/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 23/30
#
# v Fold3: preprocessor 1/1, model 23/30
#
# i Fold3: preprocessor 1/1, model 23/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 23/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 24/30
#
# v Fold3: preprocessor 1/1, model 24/30
#
# i Fold3: preprocessor 1/1, model 24/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 24/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 25/30
#
# v Fold3: preprocessor 1/1, model 25/30
#
# i Fold3: preprocessor 1/1, model 25/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 25/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 26/30
#
# v Fold3: preprocessor 1/1, model 26/30
#
# i Fold3: preprocessor 1/1, model 26/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 26/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 27/30
#
# v Fold3: preprocessor 1/1, model 27/30
#
# i Fold3: preprocessor 1/1, model 27/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 27/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 28/30
#
# v Fold3: preprocessor 1/1, model 28/30
#
# i Fold3: preprocessor 1/1, model 28/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 28/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 29/30
#
# v Fold3: preprocessor 1/1, model 29/30
#
# i Fold3: preprocessor 1/1, model 29/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 29/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 30/30
#
# v Fold3: preprocessor 1/1, model 30/30
#
# i Fold3: preprocessor 1/1, model 30/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 30/30 (predictions)
#
# i Fold4: preprocessor 1/1
#
# v Fold4: preprocessor 1/1
#
# i Fold4: preprocessor 1/1, model 1/30
#
# v Fold4: preprocessor 1/1, model 1/30
#
# i Fold4: preprocessor 1/1, model 1/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 1/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 2/30
#
# v Fold4: preprocessor 1/1, model 2/30
#
# i Fold4: preprocessor 1/1, model 2/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 2/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 3/30
#
# v Fold4: preprocessor 1/1, model 3/30
#
# i Fold4: preprocessor 1/1, model 3/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 3/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 4/30
#
# v Fold4: preprocessor 1/1, model 4/30
#
# i Fold4: preprocessor 1/1, model 4/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 4/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 5/30
#
# v Fold4: preprocessor 1/1, model 5/30
#
# i Fold4: preprocessor 1/1, model 5/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 5/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 6/30
#
# v Fold4: preprocessor 1/1, model 6/30
#
# i Fold4: preprocessor 1/1, model 6/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 6/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 7/30
#
# x Fold4: preprocessor 1/1, model 7/30:
#   Error in data$construct(): Check failed: (feature_fraction_bynode) <= ...
#
#
# i Fold4: preprocessor 1/1, model 8/30
#
# v Fold4: preprocessor 1/1, model 8/30
#
# i Fold4: preprocessor 1/1, model 8/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 8/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 9/30
#
# x Fold4: preprocessor 1/1, model 9/30:
#   Error in data$construct(): Check failed: (feature_fraction_bynode) <= ...
#
#
# i Fold4: preprocessor 1/1, model 10/30
#
# v Fold4: preprocessor 1/1, model 10/30
#
# i Fold4: preprocessor 1/1, model 10/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 10/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 11/30
#
# v Fold4: preprocessor 1/1, model 11/30
#
# i Fold4: preprocessor 1/1, model 11/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 11/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 12/30
#
# v Fold4: preprocessor 1/1, model 12/30
#
# i Fold4: preprocessor 1/1, model 12/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 12/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 13/30
#
# v Fold4: preprocessor 1/1, model 13/30
#
# i Fold4: preprocessor 1/1, model 13/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 13/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 14/30
#
# v Fold4: preprocessor 1/1, model 14/30
#
# i Fold4: preprocessor 1/1, model 14/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 14/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 15/30
#
# v Fold4: preprocessor 1/1, model 15/30
#
# i Fold4: preprocessor 1/1, model 15/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 15/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 16/30
#
# v Fold4: preprocessor 1/1, model 16/30
#
# i Fold4: preprocessor 1/1, model 16/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 16/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 17/30
#
# v Fold4: preprocessor 1/1, model 17/30
#
# i Fold4: preprocessor 1/1, model 17/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 17/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 18/30
#
# v Fold4: preprocessor 1/1, model 18/30
#
# i Fold4: preprocessor 1/1, model 18/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 18/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 19/30
#
# v Fold4: preprocessor 1/1, model 19/30
#
# i Fold4: preprocessor 1/1, model 19/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 19/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 20/30
#
# v Fold4: preprocessor 1/1, model 20/30
#
# i Fold4: preprocessor 1/1, model 20/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 20/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 21/30
#
# v Fold4: preprocessor 1/1, model 21/30
#
# i Fold4: preprocessor 1/1, model 21/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 21/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 22/30
#
# v Fold4: preprocessor 1/1, model 22/30
#
# i Fold4: preprocessor 1/1, model 22/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 22/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 23/30
#
# v Fold4: preprocessor 1/1, model 23/30
#
# i Fold4: preprocessor 1/1, model 23/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 23/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 24/30
#
# v Fold4: preprocessor 1/1, model 24/30
#
# i Fold4: preprocessor 1/1, model 24/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 24/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 25/30
#
# v Fold4: preprocessor 1/1, model 25/30
#
# i Fold4: preprocessor 1/1, model 25/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 25/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 26/30
#
# v Fold4: preprocessor 1/1, model 26/30
#
# i Fold4: preprocessor 1/1, model 26/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 26/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 27/30
#
# v Fold4: preprocessor 1/1, model 27/30
#
# i Fold4: preprocessor 1/1, model 27/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 27/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 28/30
#
# v Fold4: preprocessor 1/1, model 28/30
#
# i Fold4: preprocessor 1/1, model 28/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 28/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 29/30
#
# v Fold4: preprocessor 1/1, model 29/30
#
# i Fold4: preprocessor 1/1, model 29/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 29/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 30/30
#
# v Fold4: preprocessor 1/1, model 30/30
#
# i Fold4: preprocessor 1/1, model 30/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 30/30 (predictions)
#
# i Fold5: preprocessor 1/1
#
# v Fold5: preprocessor 1/1
#
# i Fold5: preprocessor 1/1, model 1/30
#
# v Fold5: preprocessor 1/1, model 1/30
#
# i Fold5: preprocessor 1/1, model 1/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 1/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 2/30
#
# v Fold5: preprocessor 1/1, model 2/30
#
# i Fold5: preprocessor 1/1, model 2/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 2/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 3/30
#
# v Fold5: preprocessor 1/1, model 3/30
#
# i Fold5: preprocessor 1/1, model 3/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 3/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 4/30
#
# v Fold5: preprocessor 1/1, model 4/30
#
# i Fold5: preprocessor 1/1, model 4/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 4/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 5/30
#
# v Fold5: preprocessor 1/1, model 5/30
#
# i Fold5: preprocessor 1/1, model 5/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 5/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 6/30
#
# v Fold5: preprocessor 1/1, model 6/30
#
# i Fold5: preprocessor 1/1, model 6/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 6/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 7/30
#
# x Fold5: preprocessor 1/1, model 7/30:
#   Error in data$construct(): Check failed: (feature_fraction_bynode) <= ...
#
#
# i Fold5: preprocessor 1/1, model 8/30
#
# v Fold5: preprocessor 1/1, model 8/30
#
# i Fold5: preprocessor 1/1, model 8/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 8/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 9/30
#
# x Fold5: preprocessor 1/1, model 9/30:
#   Error in data$construct(): Check failed: (feature_fraction_bynode) <= ...
#
#
# i Fold5: preprocessor 1/1, model 10/30
#
# v Fold5: preprocessor 1/1, model 10/30
#
# i Fold5: preprocessor 1/1, model 10/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 10/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 11/30
#
# v Fold5: preprocessor 1/1, model 11/30
#
# i Fold5: preprocessor 1/1, model 11/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 11/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 12/30
#
# v Fold5: preprocessor 1/1, model 12/30
#
# i Fold5: preprocessor 1/1, model 12/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 12/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 13/30
#
# v Fold5: preprocessor 1/1, model 13/30
#
# i Fold5: preprocessor 1/1, model 13/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 13/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 14/30
#
# v Fold5: preprocessor 1/1, model 14/30
#
# i Fold5: preprocessor 1/1, model 14/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 14/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 15/30
#
# v Fold5: preprocessor 1/1, model 15/30
#
# i Fold5: preprocessor 1/1, model 15/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 15/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 16/30
#
# v Fold5: preprocessor 1/1, model 16/30
#
# i Fold5: preprocessor 1/1, model 16/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 16/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 17/30
#
# v Fold5: preprocessor 1/1, model 17/30
#
# i Fold5: preprocessor 1/1, model 17/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 17/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 18/30
#
# v Fold5: preprocessor 1/1, model 18/30
#
# i Fold5: preprocessor 1/1, model 18/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 18/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 19/30
#
# v Fold5: preprocessor 1/1, model 19/30
#
# i Fold5: preprocessor 1/1, model 19/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 19/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 20/30
#
# v Fold5: preprocessor 1/1, model 20/30
#
# i Fold5: preprocessor 1/1, model 20/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 20/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 21/30
#
# v Fold5: preprocessor 1/1, model 21/30
#
# i Fold5: preprocessor 1/1, model 21/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 21/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 22/30
#
# v Fold5: preprocessor 1/1, model 22/30
#
# i Fold5: preprocessor 1/1, model 22/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 22/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 23/30
#
# v Fold5: preprocessor 1/1, model 23/30
#
# i Fold5: preprocessor 1/1, model 23/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 23/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 24/30
#
# v Fold5: preprocessor 1/1, model 24/30
#
# i Fold5: preprocessor 1/1, model 24/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 24/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 25/30
#
# v Fold5: preprocessor 1/1, model 25/30
#
# i Fold5: preprocessor 1/1, model 25/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 25/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 26/30
#
# v Fold5: preprocessor 1/1, model 26/30
#
# i Fold5: preprocessor 1/1, model 26/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 26/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 27/30
#
# v Fold5: preprocessor 1/1, model 27/30
#
# i Fold5: preprocessor 1/1, model 27/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 27/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 28/30
#
# v Fold5: preprocessor 1/1, model 28/30
#
# i Fold5: preprocessor 1/1, model 28/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 28/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 29/30
#
# v Fold5: preprocessor 1/1, model 29/30
#
# i Fold5: preprocessor 1/1, model 29/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 29/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 30/30
#
# v Fold5: preprocessor 1/1, model 30/30
#
# i Fold5: preprocessor 1/1, model 30/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 30/30 (predictions)
#
# i Fold1: preprocessor 1/1
#
# ! Fold1: preprocessor 1/1: Model failed to converge with max|grad| = 0.0020081 (tol = 0.002, compon...
#
# v Fold1: preprocessor 1/1
#
# i Fold1: preprocessor 1/1, model 1/30
#
# v Fold1: preprocessor 1/1, model 1/30
#
# i Fold1: preprocessor 1/1, model 1/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 1/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 2/30
#
# v Fold1: preprocessor 1/1, model 2/30
#
# i Fold1: preprocessor 1/1, model 2/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 2/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 3/30
#
# v Fold1: preprocessor 1/1, model 3/30
#
# i Fold1: preprocessor 1/1, model 3/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 3/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 4/30
#
# v Fold1: preprocessor 1/1, model 4/30
#
# i Fold1: preprocessor 1/1, model 4/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 4/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 5/30
#
# v Fold1: preprocessor 1/1, model 5/30
#
# i Fold1: preprocessor 1/1, model 5/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 5/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 6/30
#
# v Fold1: preprocessor 1/1, model 6/30
#
# i Fold1: preprocessor 1/1, model 6/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 6/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 7/30
#
# x Fold1: preprocessor 1/1, model 7/30:
#   Error in data$construct(): Check failed: (feature_fraction_bynode) <= ...
#
#
# i Fold1: preprocessor 1/1, model 8/30
#
# v Fold1: preprocessor 1/1, model 8/30
#
# i Fold1: preprocessor 1/1, model 8/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 8/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 9/30
#
# x Fold1: preprocessor 1/1, model 9/30:
#   Error in data$construct(): Check failed: (feature_fraction_bynode) <= ...
#
#
# i Fold1: preprocessor 1/1, model 10/30
#
# v Fold1: preprocessor 1/1, model 10/30
#
# i Fold1: preprocessor 1/1, model 10/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 10/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 11/30
#
# v Fold1: preprocessor 1/1, model 11/30
#
# i Fold1: preprocessor 1/1, model 11/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 11/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 12/30
#
# v Fold1: preprocessor 1/1, model 12/30
#
# i Fold1: preprocessor 1/1, model 12/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 12/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 13/30
#
# v Fold1: preprocessor 1/1, model 13/30
#
# i Fold1: preprocessor 1/1, model 13/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 13/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 14/30
#
# v Fold1: preprocessor 1/1, model 14/30
#
# i Fold1: preprocessor 1/1, model 14/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 14/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 15/30
#
# v Fold1: preprocessor 1/1, model 15/30
#
# i Fold1: preprocessor 1/1, model 15/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 15/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 16/30
#
# v Fold1: preprocessor 1/1, model 16/30
#
# i Fold1: preprocessor 1/1, model 16/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 16/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 17/30
#
# v Fold1: preprocessor 1/1, model 17/30
#
# i Fold1: preprocessor 1/1, model 17/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 17/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 18/30
#
# v Fold1: preprocessor 1/1, model 18/30
#
# i Fold1: preprocessor 1/1, model 18/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 18/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 19/30
#
# v Fold1: preprocessor 1/1, model 19/30
#
# i Fold1: preprocessor 1/1, model 19/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 19/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 20/30
#
# v Fold1: preprocessor 1/1, model 20/30
#
# i Fold1: preprocessor 1/1, model 20/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 20/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 21/30
#
# v Fold1: preprocessor 1/1, model 21/30
#
# i Fold1: preprocessor 1/1, model 21/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 21/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 22/30
#
# v Fold1: preprocessor 1/1, model 22/30
#
# i Fold1: preprocessor 1/1, model 22/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 22/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 23/30
#
# v Fold1: preprocessor 1/1, model 23/30
#
# i Fold1: preprocessor 1/1, model 23/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 23/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 24/30
#
# v Fold1: preprocessor 1/1, model 24/30
#
# i Fold1: preprocessor 1/1, model 24/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 24/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 25/30
#
# v Fold1: preprocessor 1/1, model 25/30
#
# i Fold1: preprocessor 1/1, model 25/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 25/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 26/30
#
# v Fold1: preprocessor 1/1, model 26/30
#
# i Fold1: preprocessor 1/1, model 26/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 26/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 27/30
#
# v Fold1: preprocessor 1/1, model 27/30
#
# i Fold1: preprocessor 1/1, model 27/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 27/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 28/30
#
# v Fold1: preprocessor 1/1, model 28/30
#
# i Fold1: preprocessor 1/1, model 28/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 28/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 29/30
#
# v Fold1: preprocessor 1/1, model 29/30
#
# i Fold1: preprocessor 1/1, model 29/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 29/30 (predictions)
#
# i Fold1: preprocessor 1/1, model 30/30
#
# v Fold1: preprocessor 1/1, model 30/30
#
# i Fold1: preprocessor 1/1, model 30/30 (extracts)
#
# i Fold1: preprocessor 1/1, model 30/30 (predictions)
#
# i Fold2: preprocessor 1/1
#
# ! Fold2: preprocessor 1/1: Model failed to converge with max|grad| = 0.00228318 (tol = 0.002, compo...
#
# v Fold2: preprocessor 1/1
#
# i Fold2: preprocessor 1/1, model 1/30
#
# v Fold2: preprocessor 1/1, model 1/30
#
# i Fold2: preprocessor 1/1, model 1/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 1/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 2/30
#
# v Fold2: preprocessor 1/1, model 2/30
#
# i Fold2: preprocessor 1/1, model 2/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 2/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 3/30
#
# v Fold2: preprocessor 1/1, model 3/30
#
# i Fold2: preprocessor 1/1, model 3/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 3/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 4/30
#
# v Fold2: preprocessor 1/1, model 4/30
#
# i Fold2: preprocessor 1/1, model 4/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 4/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 5/30
#
# v Fold2: preprocessor 1/1, model 5/30
#
# i Fold2: preprocessor 1/1, model 5/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 5/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 6/30
#
# v Fold2: preprocessor 1/1, model 6/30
#
# i Fold2: preprocessor 1/1, model 6/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 6/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 7/30
#
# x Fold2: preprocessor 1/1, model 7/30:
#   Error in data$construct(): Check failed: (feature_fraction_bynode) <= ...
#
#
# i Fold2: preprocessor 1/1, model 8/30
#
# v Fold2: preprocessor 1/1, model 8/30
#
# i Fold2: preprocessor 1/1, model 8/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 8/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 9/30
#
# x Fold2: preprocessor 1/1, model 9/30:
#   Error in data$construct(): Check failed: (feature_fraction_bynode) <= ...
#
#
# i Fold2: preprocessor 1/1, model 10/30
#
# v Fold2: preprocessor 1/1, model 10/30
#
# i Fold2: preprocessor 1/1, model 10/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 10/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 11/30
#
# v Fold2: preprocessor 1/1, model 11/30
#
# i Fold2: preprocessor 1/1, model 11/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 11/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 12/30
#
# v Fold2: preprocessor 1/1, model 12/30
#
# i Fold2: preprocessor 1/1, model 12/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 12/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 13/30
#
# v Fold2: preprocessor 1/1, model 13/30
#
# i Fold2: preprocessor 1/1, model 13/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 13/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 14/30
#
# v Fold2: preprocessor 1/1, model 14/30
#
# i Fold2: preprocessor 1/1, model 14/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 14/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 15/30
#
# v Fold2: preprocessor 1/1, model 15/30
#
# i Fold2: preprocessor 1/1, model 15/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 15/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 16/30
#
# v Fold2: preprocessor 1/1, model 16/30
#
# i Fold2: preprocessor 1/1, model 16/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 16/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 17/30
#
# v Fold2: preprocessor 1/1, model 17/30
#
# i Fold2: preprocessor 1/1, model 17/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 17/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 18/30
#
# v Fold2: preprocessor 1/1, model 18/30
#
# i Fold2: preprocessor 1/1, model 18/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 18/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 19/30
#
# v Fold2: preprocessor 1/1, model 19/30
#
# i Fold2: preprocessor 1/1, model 19/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 19/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 20/30
#
# v Fold2: preprocessor 1/1, model 20/30
#
# i Fold2: preprocessor 1/1, model 20/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 20/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 21/30
#
# v Fold2: preprocessor 1/1, model 21/30
#
# i Fold2: preprocessor 1/1, model 21/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 21/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 22/30
#
# v Fold2: preprocessor 1/1, model 22/30
#
# i Fold2: preprocessor 1/1, model 22/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 22/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 23/30
#
# v Fold2: preprocessor 1/1, model 23/30
#
# i Fold2: preprocessor 1/1, model 23/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 23/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 24/30
#
# v Fold2: preprocessor 1/1, model 24/30
#
# i Fold2: preprocessor 1/1, model 24/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 24/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 25/30
#
# v Fold2: preprocessor 1/1, model 25/30
#
# i Fold2: preprocessor 1/1, model 25/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 25/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 26/30
#
# v Fold2: preprocessor 1/1, model 26/30
#
# i Fold2: preprocessor 1/1, model 26/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 26/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 27/30
#
# v Fold2: preprocessor 1/1, model 27/30
#
# i Fold2: preprocessor 1/1, model 27/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 27/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 28/30
#
# v Fold2: preprocessor 1/1, model 28/30
#
# i Fold2: preprocessor 1/1, model 28/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 28/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 29/30
#
# v Fold2: preprocessor 1/1, model 29/30
#
# i Fold2: preprocessor 1/1, model 29/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 29/30 (predictions)
#
# i Fold2: preprocessor 1/1, model 30/30
#
# v Fold2: preprocessor 1/1, model 30/30
#
# i Fold2: preprocessor 1/1, model 30/30 (extracts)
#
# i Fold2: preprocessor 1/1, model 30/30 (predictions)
#
# i Fold3: preprocessor 1/1
#
# v Fold3: preprocessor 1/1
#
# i Fold3: preprocessor 1/1, model 1/30
#
# v Fold3: preprocessor 1/1, model 1/30
#
# i Fold3: preprocessor 1/1, model 1/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 1/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 2/30
#
# v Fold3: preprocessor 1/1, model 2/30
#
# i Fold3: preprocessor 1/1, model 2/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 2/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 3/30
#
# v Fold3: preprocessor 1/1, model 3/30
#
# i Fold3: preprocessor 1/1, model 3/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 3/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 4/30
#
# v Fold3: preprocessor 1/1, model 4/30
#
# i Fold3: preprocessor 1/1, model 4/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 4/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 5/30
#
# v Fold3: preprocessor 1/1, model 5/30
#
# i Fold3: preprocessor 1/1, model 5/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 5/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 6/30
#
# v Fold3: preprocessor 1/1, model 6/30
#
# i Fold3: preprocessor 1/1, model 6/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 6/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 7/30
#
# x Fold3: preprocessor 1/1, model 7/30:
#   Error in data$construct(): Check failed: (feature_fraction_bynode) <= ...
#
#
# i Fold3: preprocessor 1/1, model 8/30
#
# v Fold3: preprocessor 1/1, model 8/30
#
# i Fold3: preprocessor 1/1, model 8/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 8/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 9/30
#
# x Fold3: preprocessor 1/1, model 9/30:
#   Error in data$construct(): Check failed: (feature_fraction_bynode) <= ...
#
#
# i Fold3: preprocessor 1/1, model 10/30
#
# v Fold3: preprocessor 1/1, model 10/30
#
# i Fold3: preprocessor 1/1, model 10/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 10/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 11/30
#
# v Fold3: preprocessor 1/1, model 11/30
#
# i Fold3: preprocessor 1/1, model 11/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 11/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 12/30
#
# v Fold3: preprocessor 1/1, model 12/30
#
# i Fold3: preprocessor 1/1, model 12/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 12/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 13/30
#
# v Fold3: preprocessor 1/1, model 13/30
#
# i Fold3: preprocessor 1/1, model 13/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 13/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 14/30
#
# v Fold3: preprocessor 1/1, model 14/30
#
# i Fold3: preprocessor 1/1, model 14/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 14/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 15/30
#
# v Fold3: preprocessor 1/1, model 15/30
#
# i Fold3: preprocessor 1/1, model 15/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 15/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 16/30
#
# v Fold3: preprocessor 1/1, model 16/30
#
# i Fold3: preprocessor 1/1, model 16/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 16/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 17/30
#
# v Fold3: preprocessor 1/1, model 17/30
#
# i Fold3: preprocessor 1/1, model 17/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 17/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 18/30
#
# v Fold3: preprocessor 1/1, model 18/30
#
# i Fold3: preprocessor 1/1, model 18/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 18/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 19/30
#
# v Fold3: preprocessor 1/1, model 19/30
#
# i Fold3: preprocessor 1/1, model 19/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 19/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 20/30
#
# v Fold3: preprocessor 1/1, model 20/30
#
# i Fold3: preprocessor 1/1, model 20/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 20/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 21/30
#
# v Fold3: preprocessor 1/1, model 21/30
#
# i Fold3: preprocessor 1/1, model 21/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 21/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 22/30
#
# v Fold3: preprocessor 1/1, model 22/30
#
# i Fold3: preprocessor 1/1, model 22/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 22/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 23/30
#
# v Fold3: preprocessor 1/1, model 23/30
#
# i Fold3: preprocessor 1/1, model 23/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 23/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 24/30
#
# v Fold3: preprocessor 1/1, model 24/30
#
# i Fold3: preprocessor 1/1, model 24/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 24/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 25/30
#
# v Fold3: preprocessor 1/1, model 25/30
#
# i Fold3: preprocessor 1/1, model 25/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 25/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 26/30
#
# v Fold3: preprocessor 1/1, model 26/30
#
# i Fold3: preprocessor 1/1, model 26/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 26/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 27/30
#
# v Fold3: preprocessor 1/1, model 27/30
#
# i Fold3: preprocessor 1/1, model 27/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 27/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 28/30
#
# v Fold3: preprocessor 1/1, model 28/30
#
# i Fold3: preprocessor 1/1, model 28/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 28/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 29/30
#
# v Fold3: preprocessor 1/1, model 29/30
#
# i Fold3: preprocessor 1/1, model 29/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 29/30 (predictions)
#
# i Fold3: preprocessor 1/1, model 30/30
#
# v Fold3: preprocessor 1/1, model 30/30
#
# i Fold3: preprocessor 1/1, model 30/30 (extracts)
#
# i Fold3: preprocessor 1/1, model 30/30 (predictions)
#
# i Fold4: preprocessor 1/1
#
# ! Fold4: preprocessor 1/1: Model failed to converge with max|grad| = 0.0021884 (tol = 0.002, compon...
#
# v Fold4: preprocessor 1/1
#
# i Fold4: preprocessor 1/1, model 1/30
#
# v Fold4: preprocessor 1/1, model 1/30
#
# i Fold4: preprocessor 1/1, model 1/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 1/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 2/30
#
# v Fold4: preprocessor 1/1, model 2/30
#
# i Fold4: preprocessor 1/1, model 2/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 2/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 3/30
#
# v Fold4: preprocessor 1/1, model 3/30
#
# i Fold4: preprocessor 1/1, model 3/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 3/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 4/30
#
# v Fold4: preprocessor 1/1, model 4/30
#
# i Fold4: preprocessor 1/1, model 4/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 4/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 5/30
#
# v Fold4: preprocessor 1/1, model 5/30
#
# i Fold4: preprocessor 1/1, model 5/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 5/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 6/30
#
# v Fold4: preprocessor 1/1, model 6/30
#
# i Fold4: preprocessor 1/1, model 6/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 6/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 7/30
#
# x Fold4: preprocessor 1/1, model 7/30:
#   Error in data$construct(): Check failed: (feature_fraction_bynode) <= ...
#
#
# i Fold4: preprocessor 1/1, model 8/30
#
# v Fold4: preprocessor 1/1, model 8/30
#
# i Fold4: preprocessor 1/1, model 8/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 8/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 9/30
#
# x Fold4: preprocessor 1/1, model 9/30:
#   Error in data$construct(): Check failed: (feature_fraction_bynode) <= ...
#
#
# i Fold4: preprocessor 1/1, model 10/30
#
# v Fold4: preprocessor 1/1, model 10/30
#
# i Fold4: preprocessor 1/1, model 10/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 10/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 11/30
#
# v Fold4: preprocessor 1/1, model 11/30
#
# i Fold4: preprocessor 1/1, model 11/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 11/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 12/30
#
# v Fold4: preprocessor 1/1, model 12/30
#
# i Fold4: preprocessor 1/1, model 12/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 12/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 13/30
#
# v Fold4: preprocessor 1/1, model 13/30
#
# i Fold4: preprocessor 1/1, model 13/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 13/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 14/30
#
# v Fold4: preprocessor 1/1, model 14/30
#
# i Fold4: preprocessor 1/1, model 14/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 14/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 15/30
#
# v Fold4: preprocessor 1/1, model 15/30
#
# i Fold4: preprocessor 1/1, model 15/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 15/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 16/30
#
# v Fold4: preprocessor 1/1, model 16/30
#
# i Fold4: preprocessor 1/1, model 16/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 16/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 17/30
#
# v Fold4: preprocessor 1/1, model 17/30
#
# i Fold4: preprocessor 1/1, model 17/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 17/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 18/30
#
# v Fold4: preprocessor 1/1, model 18/30
#
# i Fold4: preprocessor 1/1, model 18/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 18/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 19/30
#
# v Fold4: preprocessor 1/1, model 19/30
#
# i Fold4: preprocessor 1/1, model 19/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 19/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 20/30
#
# v Fold4: preprocessor 1/1, model 20/30
#
# i Fold4: preprocessor 1/1, model 20/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 20/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 21/30
#
# v Fold4: preprocessor 1/1, model 21/30
#
# i Fold4: preprocessor 1/1, model 21/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 21/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 22/30
#
# v Fold4: preprocessor 1/1, model 22/30
#
# i Fold4: preprocessor 1/1, model 22/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 22/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 23/30
#
# v Fold4: preprocessor 1/1, model 23/30
#
# i Fold4: preprocessor 1/1, model 23/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 23/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 24/30
#
# v Fold4: preprocessor 1/1, model 24/30
#
# i Fold4: preprocessor 1/1, model 24/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 24/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 25/30
#
# v Fold4: preprocessor 1/1, model 25/30
#
# i Fold4: preprocessor 1/1, model 25/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 25/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 26/30
#
# v Fold4: preprocessor 1/1, model 26/30
#
# i Fold4: preprocessor 1/1, model 26/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 26/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 27/30
#
# v Fold4: preprocessor 1/1, model 27/30
#
# i Fold4: preprocessor 1/1, model 27/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 27/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 28/30
#
# v Fold4: preprocessor 1/1, model 28/30
#
# i Fold4: preprocessor 1/1, model 28/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 28/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 29/30
#
# v Fold4: preprocessor 1/1, model 29/30
#
# i Fold4: preprocessor 1/1, model 29/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 29/30 (predictions)
#
# i Fold4: preprocessor 1/1, model 30/30
#
# v Fold4: preprocessor 1/1, model 30/30
#
# i Fold4: preprocessor 1/1, model 30/30 (extracts)
#
# i Fold4: preprocessor 1/1, model 30/30 (predictions)
#
# i Fold5: preprocessor 1/1
#
# ! Fold5: preprocessor 1/1: Model failed to converge with max|grad| = 0.00283353 (tol = 0.002, compo...
#
# v Fold5: preprocessor 1/1
#
# i Fold5: preprocessor 1/1, model 1/30
#
# v Fold5: preprocessor 1/1, model 1/30
#
# i Fold5: preprocessor 1/1, model 1/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 1/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 2/30
#
# v Fold5: preprocessor 1/1, model 2/30
#
# i Fold5: preprocessor 1/1, model 2/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 2/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 3/30
#
# v Fold5: preprocessor 1/1, model 3/30
#
# i Fold5: preprocessor 1/1, model 3/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 3/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 4/30
#
# v Fold5: preprocessor 1/1, model 4/30
#
# i Fold5: preprocessor 1/1, model 4/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 4/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 5/30
#
# v Fold5: preprocessor 1/1, model 5/30
#
# i Fold5: preprocessor 1/1, model 5/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 5/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 6/30
#
# v Fold5: preprocessor 1/1, model 6/30
#
# i Fold5: preprocessor 1/1, model 6/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 6/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 7/30
#
# x Fold5: preprocessor 1/1, model 7/30:
#   Error in data$construct(): Check failed: (feature_fraction_bynode) <= ...
#
#
# i Fold5: preprocessor 1/1, model 8/30
#
# v Fold5: preprocessor 1/1, model 8/30
#
# i Fold5: preprocessor 1/1, model 8/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 8/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 9/30
#
# x Fold5: preprocessor 1/1, model 9/30:
#   Error in data$construct(): Check failed: (feature_fraction_bynode) <= ...
#
#
# i Fold5: preprocessor 1/1, model 10/30
#
# v Fold5: preprocessor 1/1, model 10/30
#
# i Fold5: preprocessor 1/1, model 10/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 10/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 11/30
#
# v Fold5: preprocessor 1/1, model 11/30
#
# i Fold5: preprocessor 1/1, model 11/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 11/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 12/30
#
# v Fold5: preprocessor 1/1, model 12/30
#
# i Fold5: preprocessor 1/1, model 12/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 12/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 13/30
#
# v Fold5: preprocessor 1/1, model 13/30
#
# i Fold5: preprocessor 1/1, model 13/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 13/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 14/30
#
# v Fold5: preprocessor 1/1, model 14/30
#
# i Fold5: preprocessor 1/1, model 14/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 14/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 15/30
#
# v Fold5: preprocessor 1/1, model 15/30
#
# i Fold5: preprocessor 1/1, model 15/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 15/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 16/30
#
# v Fold5: preprocessor 1/1, model 16/30
#
# i Fold5: preprocessor 1/1, model 16/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 16/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 17/30
#
# v Fold5: preprocessor 1/1, model 17/30
#
# i Fold5: preprocessor 1/1, model 17/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 17/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 18/30
#
# v Fold5: preprocessor 1/1, model 18/30
#
# i Fold5: preprocessor 1/1, model 18/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 18/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 19/30
#
# v Fold5: preprocessor 1/1, model 19/30
#
# i Fold5: preprocessor 1/1, model 19/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 19/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 20/30
#
# v Fold5: preprocessor 1/1, model 20/30
#
# i Fold5: preprocessor 1/1, model 20/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 20/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 21/30
#
# v Fold5: preprocessor 1/1, model 21/30
#
# i Fold5: preprocessor 1/1, model 21/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 21/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 22/30
#
# v Fold5: preprocessor 1/1, model 22/30
#
# i Fold5: preprocessor 1/1, model 22/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 22/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 23/30
#
# v Fold5: preprocessor 1/1, model 23/30
#
# i Fold5: preprocessor 1/1, model 23/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 23/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 24/30
#
# v Fold5: preprocessor 1/1, model 24/30
#
# i Fold5: preprocessor 1/1, model 24/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 24/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 25/30
#
# v Fold5: preprocessor 1/1, model 25/30
#
# i Fold5: preprocessor 1/1, model 25/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 25/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 26/30
#
# v Fold5: preprocessor 1/1, model 26/30
#
# i Fold5: preprocessor 1/1, model 26/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 26/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 27/30
#
# v Fold5: preprocessor 1/1, model 27/30
#
# i Fold5: preprocessor 1/1, model 27/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 27/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 28/30
#
# v Fold5: preprocessor 1/1, model 28/30
#
# i Fold5: preprocessor 1/1, model 28/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 28/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 29/30
#
# v Fold5: preprocessor 1/1, model 29/30
#
# i Fold5: preprocessor 1/1, model 29/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 29/30 (predictions)
#
# i Fold5: preprocessor 1/1, model 30/30
#
# v Fold5: preprocessor 1/1, model 30/30
#
# i Fold5: preprocessor 1/1, model 30/30 (extracts)
#
# i Fold5: preprocessor 1/1, model 30/30 (predictions)

# %%
# 8. Collect and rank results
ranked_results <- rank_results(tuning_results, rank_metric = "mcc")
ranked_results %>% 
    group_by(wflow_id) %>% 
    filter(rank == min(rank))
# Out:
#   wflow_id                 .config               .metric mean
# 1 no_encoding_lightgbm     Preprocessor1_Model14 mcc     0.9835997
# 2 no_encoding_lightgbm     Preprocessor1_Model14 roc_auc 0.9969069
# 3 effect_encoding_lightgbm Preprocessor1_Model14 mcc     0.9823623
# 4 effect_encoding_lightgbm Preprocessor1_Model14 roc_auc 0.9967609
#   std_err       n preprocessor model      rank
# 1 0.00011313257 5 recipe       boost_tree 1
# 2 0.00002975685 5 recipe       boost_tree 1
# 3 0.00009155291 5 recipe       boost_tree 4
# 4 0.00001825030 5 recipe       boost_tree 4

# %%
# 9. Select the best workflow and finalize it
best_workflow <- tuning_results %>%
  extract_workflow_set_result(ranked_results$wflow_id[1]) %>%
  select_best(metric = "mcc")

final_workflow <- tuning_results %>%
  extract_workflow(ranked_results$wflow_id[1]) %>%
  finalize_workflow(best_workflow)

# %%
# Best model
final_workflow
# Out:
# == Workflow ====================================================================
# Preprocessor: Recipe
# Model: boost_tree()
#
# -- Preprocessor ----------------------------------------------------------------
# 3 Recipe Steps
#
# * step_rm()
# * step_normalize()
# * step_zv()
#
# -- Model -----------------------------------------------------------------------
# Boosted Tree Model Specification (classification)
#
# Main Arguments:
#   mtry = 12
#   trees = 651
#   min_n = 15
#   tree_depth = 6
#   learn_rate = 0.0927143550217526
#   loss_reduction = 0.000000468484929747033
#   sample_size = 0.54368191759102
#
# Computational engine: lightgbm

# %%
# 10. Fit the final model on the entire training data
final_model <- fit(final_workflow, data = train_data)

# %%
# 11. Make predictions on test data 
test_data <- test_imputed %>% 
  mutate_if(is.character, as.factor)

predictions <- predict(final_model, new_data = test_data)

# %%
# formatting submission
submission %>% 
    mutate(class = predictions[[1]],
           class = ifelse(class == 1, "p", "e")) %>% 
    write_csv("Data/submission_rare_noencoded_lgbm_tuned_R.csv")

# %%
# Saving workflows that produced models:
# wf_1: Encoded Recipe
wf_1_best <- tuning_results %>%
  extract_workflow_set_result(ranked_results$wflow_id[7]) %>%
  select_best(metric = "mcc")

wf_1 <- tuning_results %>%
  extract_workflow(ranked_results$wflow_id[7]) %>%
  finalize_workflow(wf_1_best)

# wf_1: Non Encoded Recipe
wf_2_best <- tuning_results %>%
  extract_workflow_set_result(ranked_results$wflow_id[1]) %>%
  select_best(metric = "mcc")

wf_2 <- tuning_results %>%
  extract_workflow(ranked_results$wflow_id[1]) %>%
  finalize_workflow(wf_2_best)

workflow_list <- list(
  wf_1 = wf_1,
  wf_2 = wf_2
)
saveRDS(workflow_list, "Data/1_initial_models_wf.rds")
